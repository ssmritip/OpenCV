# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread('D:/PythonProjects/opencv/Assets/face1.jpg')
img1 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
print(img.shape)
# Out:
# (408, 612, 3)

# %%
# Display using Matplotlib
plt.imshow(img1)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(611.5), np.float64(407.5), np.float64(-0.5))

# %%
gray_img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
print(gray_img.shape)
# Out:
# (408, 612)

# %% [markdown]
# #### Haar Cascade Classifier

# %%
face_clf = cv.CascadeClassifier(
    cv.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %%
face = face_clf.detectMultiScale(
    gray_img, scaleFactor=1.1, minNeighbors=5, minSize=(50, 50)
)

for (x, y, w, h) in face:
    cv.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 3)

# %%
face
# Out:
# array([[338,  84,  64,  64]], dtype=int32)

# %%
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(611.5), np.float64(407.5), np.float64(-0.5))
